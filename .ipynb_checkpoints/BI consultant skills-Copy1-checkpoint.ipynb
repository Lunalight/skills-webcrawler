# %%
import re
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from itertools import chain
import time
import requests
import random
import pandas as pd
import matplotlib.pyplot as plt
from goose3 import Goose
from collections import Counter

# %%
program_languages=['bash','r','python','java','c++','c#', 'f#', 'ruby','perl','matlab','javascript','scala','php']
analysis_software=['alteryx', 'excel','tableau', 'power bi', 'powerbi', 'qlikview', 'qlik','d3.js','sas','sap','spss','d3','saas','pandas','numpy','scipy','sps','spotfire','scikits.learn','splunk','powerpoint','h2o']
bigdata_tool=['hadoop','mapreduce','spark','pig','hive','shark','oozie','zookeeper','flume','mahout']
databases=['sql','nosql','hbase','cassandra','mongodb','mysql','mssql','postgresql','oracle db','rdbms']
machine_learning = ['keras', 'scikit-learn', 'tensorflow', 'caffe', 'datarobot', 'theano', 'torch']
overall_dict = program_languages + analysis_software + bigdata_tool + databases + machine_learning

soft_skills = ["analytisch vermogen", "projectmanagement", "proactief", "communicatieve vaardigheden", "uitdrukkingsvaardigheden", "agile", "scrum", 
"advies", "adviseur", "werkt samen", "werkt nauw samen", "samenwerken", "analytisch", "planmatig", "zelfstandig", "enthousiast", "vertalen", "inventariseren", "analyseren", 
"realiseren", "ondernemen", "adviseer", "oplossingsgericht", "klantgericht", "gedreven", "creatief", "meedenkend", "resultaatgericht", "oplossingsgericht",
"prioriteren", "presenteren"]

# %%
def keywords_extract(url):
    g = Goose()
    article = g.extract(url=url)
    text = article.cleaned_text
    text = re.sub("[^a-zA-Z+3]"," ", text) #get rid of things that aren't words; 3 for d3 and + for c++
    text = text.lower().split()
    stops = set(stopwords.words("english")) #filter out stop words in english language
    text = [w for w in text if not w in stops]
    text = list(set(text))
    keywords = [str(word) for word in text if word in overall_dict]
    return keywords

# %%
def keywords_f(soup_obj):
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    text = soup_obj.get_text() 
    lines = (line.strip() for line in text.splitlines()) # break into line
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    text = ''.join(chunk for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
    try:
        text = text.decode('utf-8') # Need this as some websites aren't formatted
    except:                                                          
        return                                                       
    text = re.sub("[^a-zA-Z+3]"," ", text)  
    text = re.sub(r"([a-z])([A-Z])", r"\1 \2", text) # Fix spacing issue from merged words
    text = text.lower()
    text = re.sub(('power bi'), 'powerbi', text) # catch power bi before tokenization
    text = text.split()  
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
    text = list(set(text)) #only care about if a word appears, don't care about the frequency
    keywords = [str(word) for word in text if word in overall_dict] #if a skill keyword is found, return it.
    return keywords

# %%
def communication_skills_f(soup_obj):
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    text = soup_obj.get_text() 
    lines = (line.strip() for line in text.splitlines()) # break into line
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    text = ''.join(chunk for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
    try:
        text = text.decode('utf-8') # Need this as some websites aren't formatted
    except:                                                          
        return                                                       
    text = re.sub("[^a-zA-Z+3]"," ", text)  
    text = re.sub(r"([a-z])([A-Z])", r"\1 \2", text) # Fix spacing issue from merged words
    text = text.lower()
    skills = [word for word in soft_skills if word in text] 
    return skills

# %%
base_url = "http://www.indeed.nl"    
#change the start_url can scrape different cities.
start_url = "http://www.indeed.nl/jobs?q=BI+consultant&l="
resp = requests.get(start_url)
start_soup = BeautifulSoup(resp.content, 'lxml', from_encoding='utf-8')
urls=start_soup.find_all('a',{'rel':'nofollow','target':'_blank'})
urls = [link['href'] for link in urls] 
num_found = start_soup.find(id = 'searchCount').string.encode('utf-8').split() #this returns the total number of results
num_jobs = num_found[-1].decode('utf-8').split(',')
num_jobs = [x.replace('.', '') for x in num_jobs]

if len(num_jobs)>=2:
    num_jobs = int(num_jobs[0]) * 1000 + int(num_jobs[1])
else:
    num_jobs = int(num_jobs[0])
num_pages = int(num_jobs/10) #calculates how many pages needed to do the scraping

job_keywords=[]
print('There are %d jobs found and we need to extract %d pages.'%(num_jobs,num_pages))
print('extracting first page of job searching results')
# Out:
# There are 808 jobs found and we need to extract 80 pages.
# extracting first page of job searching results

# %%
# # prevent the driver stopping due to the unexpectedAlertBehaviour.
# webdriver.DesiredCapabilities.FIREFOX["unexpectedAlertBehaviour"] = "accept"
# get_info = True
# driver = webdriver.Firefox(executable_path=r'C:\Users\emily\Documents\ML course\geckodriver.exe')
# # set a page load time limit so that don't have to wait forever if the links are broken.
# driver.set_page_load_timeout(15)
# for i in range(len(urls)):
#     get_info = True
#     try:
#         driver.get(base_url+urls[i])
#     except TimeoutException:
#         get_info = False
#         continue
#     j = random.randint(1000,2200)/1000.0
#     time.sleep(j) #waits for a random time so that the website don't consider you as a bot
#     if get_info:
#         soup=BeautifulSoup(driver.page_source, 'lxml')
#         print('extracting %d job keywords...' % i)
#         single_job = keywords_f(soup)
#         other_job = communication_skills_f(soup)
#         print(single_job, other_job, len(soup))
#         print(driver.current_url)
#         job_keywords.append([single_job, other_job])

            
# driver.quit()

# skills_dict = list()
# for lss in job_keywords:
#     for ls in lss:
#         for word in ls:
#             if word in soft_skills:
#                 skills_dict.append(('soft skills', word))
#             elif word in program_languages:
#                 skills_dict.append(('program languages', word))
#             elif word in analysis_software:
#                 skills_dict.append(('analysis software', word))
#             elif word in bigdata_tool:
#                 skills_dict.append(('big data tooling', word))
#             elif word in databases:
#                 skills_dict.append(('databases', word))
#             elif word in machine_learning:
#                 skills_dict.append(('machine learning', word))
                
# skills_count_dict = Counter(skills_dict)
# skills_count_dict.keys()
# df = pd.DataFrame()
# df['Skill'] = skills_count_dict.keys()
# df['Count'] = skills_count_dict.values()
# df['Ranking'] = df['Count']/float(len(job_keywords))
# df[['Category', 'Skill']] = df['Skill'].apply(pd.Series)
# df= df[['Category', 'Skill', 'Count', 'Ranking']]
# df
# Out:
# extracting 0 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl38umr59u1hesj&from=serp&alid=3&advn=2180790811884654
# extracting 1 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl38upje9u1h82t&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 2 job keywords...
# ['sas', 'sql'] ['analytisch', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71870903e1c04534&tk=1cl38usen9u1h8e7&from=serp&alid=3&advn=2723736679244663
# extracting 3 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl38uucs9u1hbta&from=serp&alid=3&advn=2421485629829485
# extracting 4 job keywords...
# ['powerbi', 'sas', 'sql'] ['agile', 'scrum', 'enthousiast', 'vertalen', 'ondernemen', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=64bbd4e2bfb3ef23&from=serp&vjs=3
# extracting 5 job keywords...
# [] ['inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=06b8129ce00d51e0&from=serp&vjs=3
# extracting 6 job keywords...
# [] ['advies', 'adviseur', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=e0771b58557a838a&from=serp&vjs=3
# extracting 7 job keywords...
# ['powerbi', 'sql'] ['zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=ee47624aa5b18954&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'powerbi', 'sql'] ['proactief', 'communicatieve vaardigheden', 'advies', 'werkt nauw samen', 'analytisch', 'planmatig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=69e2493bfb1ad195&from=serp&vjs=3
# extracting 9 job keywords...
# [] ['gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6f4023c70f7edeb2&from=serp&vjs=3
# extracting 10 job keywords...
# ['powerbi', 'qlik', 'sql'] ['adviseur', 'analytisch', 'vertalen', 'oplossingsgericht', 'klantgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4b20794365970d75&from=serp&vjs=3
# extracting 11 job keywords...
# ['sql', 'sap'] ['communicatieve vaardigheden', 'vertalen', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=39a4a955833d121d&from=serp&vjs=3
# extracting 12 job keywords...
# ['sql', 'powerbi'] ['proactief', 'zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=534592f8a78cd2fa&from=serp&vjs=3
# extracting 13 job keywords...
# ['sql', 'excel', 'tableau'] ['agile', 'advies', 'samenwerken', 'ondernemen', 'adviseer', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1006db74a19f404a&from=serp&vjs=3
# extracting 14 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl38vqve9u1hasc&from=serp&alid=3&advn=8245509577778884
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl38vtn79u1hfud&from=serp&alid=3&advn=6124692058421937
#              Category                        Skill  Count  Ranking
# 0   analysis software                      powerbi     14  0.43750
# 1           databases                          sql     22  0.68750
# 2         soft skills                       advies     10  0.31250
# 3         soft skills                  werkt samen      6  0.18750
# 4         soft skills                  zelfstandig      8  0.25000
# 5         soft skills                  enthousiast      8  0.25000
# 6   program languages                            r      5  0.15625
# 7         soft skills                     vertalen     12  0.37500
# 8         soft skills                     gedreven     11  0.34375
# 9   analysis software                          sas      6  0.18750
# 10        soft skills                   analytisch      8  0.25000
# 11        soft skills             resultaatgericht      4  0.12500
# 12        soft skills                  presenteren      2  0.06250
# 13        soft skills                   analyseren      6  0.18750
# 14        soft skills                 klantgericht     10  0.31250
# 15        soft skills                     creatief      2  0.06250
# 16        soft skills                        agile      6  0.18750
# 17        soft skills                        scrum      4  0.12500
# 18        soft skills                   ondernemen      7  0.21875
# 19        soft skills               inventariseren      4  0.12500
# 20        soft skills                   realiseren      4  0.12500
# 21        soft skills                     adviseer      4  0.12500
# 22        soft skills                     adviseur      4  0.12500
# 23  analysis software                          sap      6  0.18750
# 24        soft skills                    proactief      4  0.12500
# 25        soft skills  communicatieve vaardigheden      4  0.12500
# 26        soft skills             werkt nauw samen      2  0.06250
# 27        soft skills                    planmatig      2  0.06250
# 28  analysis software                         qlik      2  0.06250
# 29        soft skills            oplossingsgericht      4  0.12500
# 30  analysis software                        excel      2  0.06250
# 31  analysis software                      tableau      2  0.06250
# 32        soft skills                  samenwerken      2  0.06250
# 33  program languages                       python      2  0.06250
# 34   big data tooling                       hadoop      2  0.06250
# 35  program languages                         java      2  0.06250
# 36  program languages                          c++      2  0.06250
# 37   big data tooling                        spark      2  0.06250
# 38          databases                        nosql      2  0.06250

# %%
# prevent the driver stopping due to the unexpectedAlertBehaviour.
webdriver.DesiredCapabilities.FIREFOX["unexpectedAlertBehaviour"] = "accept"
get_info = True
driver = webdriver.Firefox(executable_path=r'C:\Users\emily\Documents\ML course\geckodriver.exe')
# set a page load time limit so that don't have to wait forever if the links are broken.
driver.set_page_load_timeout(15)

for k in range(1,num_pages + 1):
#this 5 pages reopen the browser is to prevent connection refused error.
    if k%5==0.0:
        driver.quit()
        driver=webdriver.Firefox(executable_path=r'C:\Users\emily\Documents\ML course\geckodriver.exe')
        driver.set_page_load_timeout(15)

    current_url = start_url + "&start=" + str(k*10)
    print('extracting %d page of job searching results...' % k)
    resp = requests.get(current_url)
    current_soup = BeautifulSoup(resp.content, 'lxml')
    current_urls = current_soup.findAll('a',{'rel':'nofollow','target':'_blank'})
    current_urls = [link['href'] for link in current_urls]
    
    for i in range(len(current_urls)):
        get_info = True
        try:
            driver.get(base_url + current_urls[i])
        except TimeoutException:
            get_info = False
            continue 
        j = random.randint(1500,3200)/1000.0
        time.sleep(j) #waits for a random time
        if get_info:
            soup=BeautifulSoup(driver.page_source, 'lxml')
            print('extracting %d job keywords...' % i)
        single_job = keywords_f(soup)
        other_job = communication_skills_f(soup)
        print(single_job, other_job, len(soup))
        print(driver.current_url)
        job_keywords.append([driver.current_url,single_job, other_job])

            
driver.quit()

skills_dict = list()
for lss in job_keywords:
    for ls in lss:
        for word in ls:
            if word in soft_skills:
                skills_dict.append(('soft skills', word))
            elif word in program_languages:
                skills_dict.append(('program languages', word))
            elif word in analysis_software:
                skills_dict.append(('analysis software', word))
            elif word in bigdata_tool:
                skills_dict.append(('big data tooling', word))
            elif word in databases:
                skills_dict.append(('databases', word))
            elif word in machine_learning:
                skills_dict.append(('machine learning', word))
                
skills_count_dict = Counter(skills_dict)
skills_count_dict.keys()
df = pd.DataFrame()
df['Skill'] = skills_count_dict.keys()
df['Count'] = skills_count_dict.values()
df['Ranking'] = df['Count']/float(len(job_keywords))
df[['Category', 'Skill']] = df['Skill'].apply(pd.Series)
df= df[['Category', 'Skill', 'Count', 'Ranking']]
df
# Out:
# extracting 1 page of job searching results...
# extracting 0 job keywords...
# ['sap', 'sas', 'sql'] ['zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=783cab236ecfa412&from=serp&vjs=3
# extracting 1 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3957b49ooidma&from=serp&alid=3&advn=6124692058421937
# extracting 2 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl395an49ooi8pu&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 3 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl395eo99ooicgr&from=serp&alid=3&advn=713903982049763
# extracting 4 job keywords...
# ['powerbi'] ['adviseur', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=673bd43e507ca1c0&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap', 'powerbi', 'sql'] ['communicatieve vaardigheden', 'advies', 'analytisch', 'zelfstandig', 'vertalen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0471b7570c5b9c19&from=serp&vjs=3
# extracting 6 job keywords...
# ['hadoop'] ['analytisch vermogen', 'communicatieve vaardigheden', 'agile', 'analytisch', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'adviseer', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=f4d29a2daf1cc2f2&from=serp&vjs=3
# extracting 7 job keywords...
# ['powerbi', 'qlik', 'sql'] ['communicatieve vaardigheden', 'zelfstandig', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6912fe929ce8dd38&from=serp&vjs=3
# extracting 8 job keywords...
# ['python', 'sql', 'sap', 'r', 'javascript'] ['gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=829e83633ebe6414&from=serp&vjs=3
# extracting 9 job keywords...
# [] ['uitdrukkingsvaardigheden', 'adviseur', 'analytisch', 'enthousiast', 'analyseren', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=a9c8302063137477&from=serp&vjs=3
# extracting 10 job keywords...
# ['powerbi', 'python', 'php', 'r', 'sas', 'sql'] ['communicatieve vaardigheden', 'analytisch', 'zelfstandig', 'vertalen', 'inventariseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4c4875a1a70c3e6f&from=serp&vjs=3
# extracting 11 job keywords...
# ['sap', 'powerbi', 'sql'] ['zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=2e47737f05841129&from=serp&vjs=3
# extracting 12 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&from=serp&vjs=3
# extracting 13 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl396g719ooifa3&from=serp&alid=3&advn=2421485629829485
# extracting 14 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl396jo39ooideg&from=serp&alid=3&advn=8245509577778884
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl396mu29ooi8jh&from=serp&alid=3&advn=2180790811884654
# extracting 2 page of job searching results...
# extracting 0 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl396qon9ooifp5&from=serp&alid=3&advn=6124692058421937
# extracting 1 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl396ttm9ooi9el&from=serp&alid=3&advn=8245509577778884
# extracting 2 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3970rg9ooi88q&from=serp&alid=3&advn=713903982049763
# extracting 3 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39745q9ooie89&from=serp&alid=3&advn=2421485629829485
# extracting 4 job keywords...
# ['sap', 'python', 'r'] ['agile', 'scrum'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1ed72ba09a220582&from=serp&vjs=3
# extracting 5 job keywords...
# ['r'] ['adviseur', 'zelfstandig', 'realiseren', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=bde50bf12f38b96a&from=serp&vjs=3
# extracting 6 job keywords...
# ['qlik'] ['werkt samen', 'analyseren', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=a084b2aebeab659d&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap', 'powerbi'] ['agile', 'scrum', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=7388e98473ad2585&from=serp&vjs=3
# extracting 8 job keywords...
# [] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=836c4cf45d35506a&from=serp&vjs=3
# extracting 9 job keywords...
# ['sql', 'excel', 'sap', 'powerbi'] ['analytisch', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b50f66fa9a6d7b7c&from=serp&vjs=3
# extracting 10 job keywords...
# ['python', 'sql', 'spotfire', 'tableau', 'powerbi', 'r'] ['zelfstandig', 'vertalen', 'analyseren', 'realiseren', 'ondernemen', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6377c95ce2fe324c&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['samenwerken', 'enthousiast', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1499b7b91d1b8f91&from=serp&vjs=3
# extracting 12 job keywords...
# ['sql', 'powerbi'] ['communicatieve vaardigheden', 'zelfstandig', 'realiseren', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0e5d26889264c639&from=serp&vjs=3
# extracting 13 job keywords...
# ['sap'] ['proactief', 'agile', 'scrum'] 1
# https://www.indeed.nl/vacature-bekijken?jk=a97867cf3ce8314b&from=serp&vjs=3
# extracting 14 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl398a399ooicv9&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl398dpr9ooiaaa&from=serp&alid=3&advn=2180790811884654
# extracting 3 page of job searching results...
# extracting 0 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl398gts9ooid0p&from=serp&alid=3&advn=8245509577778884
# extracting 1 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl398kkd9ooieiu&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl398n539ooiccf&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=eca2335662518a1b&from=serp&vjs=3
# extracting 4 job keywords...
# [] ['agile', 'scrum'] 1
# https://www.indeed.nl/vacature-bekijken?jk=97d4dc602683ce38&from=serp&vjs=3
# extracting 5 job keywords...
# ['sql', 'java', 'tableau', 'powerbi', 'spss'] ['agile', 'scrum', 'samenwerken', 'analytisch', 'enthousiast', 'ondernemen', 'adviseer', 'klantgericht', 'prioriteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9c33ec392d1c87b5&from=serp&vjs=3
# extracting 6 job keywords...
# ['powerbi'] ['communicatieve vaardigheden', 'advies', 'analytisch', 'zelfstandig', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=c4a0d6ff5f8c994d&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap', 'qlik', 'r', 'excel'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=769b7ad731f94603&from=serp&vjs=3
# extracting 8 job keywords...
# ['powerbi', 'tableau', 'sql'] ['analytisch vermogen', 'analytisch', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=12fa3f497cac58c4&from=serp&vjs=3
# extracting 9 job keywords...
# ['sap', 'qlik', 'sas', 'tableau', 'sql'] ['zelfstandig', 'ondernemen', 'gedreven'] 1
# https://www.indeed.nl/cmp/DIKW-Intelligence/jobs/Medior-Business-Intelligence-Consultant-474f0dbd6118afb5?vjs=3
# extracting 10 job keywords...
# ['r'] ['advies', 'zelfstandig', 'vertalen', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=c826939481d4ac15&from=serp&vjs=3
# extracting 11 job keywords...
# ['hadoop', 'sas'] ['proactief', 'samenwerken', 'vertalen', 'realiseren', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d79311ab14a80c50&from=serp&vjs=3
# extracting 12 job keywords...
# ['qlik', 'qlikview', 'sql'] ['vertalen', 'analyseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1b48cabc6d81719d&from=serp&vjs=3
# extracting 13 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl399tu39ooi84k&from=serp&alid=3&advn=6124692058421937
# extracting 14 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39a0uh9ooieb9&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39a5gs9ooiaub&from=serp&alid=3&advn=2180790811884654
# extracting 4 page of job searching results...
# extracting 0 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39aaqi9ooibiv&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 1 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39aeu29ooid7l&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39ai5g9ooi9ks&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['sql', 'sap', 'powerbi', 'qlik'] ['proactief', 'zelfstandig', 'vertalen', 'ondernemen', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=593dd2da0ea07b87&from=serp&vjs=3
# extracting 4 job keywords...
# ['sap'] ['zelfstandig', 'enthousiast', 'analyseren'] 1
# https://www.indeed.nl/cmp/Sapmatch-B.V./jobs/SAP-Bw-Consultant-Plus-Jaar-Relevante-Ervaring-09b6eb23c38fadf6?vjs=3
# extracting 5 job keywords...
# ['sap', 'qlik'] ['communicatieve vaardigheden', 'analytisch', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=5413bce73ef018b0&from=serp&vjs=3
# extracting 6 job keywords...
# [] ['agile', 'scrum'] 1
# https://www.indeed.nl/vacature-bekijken?jk=97d4dc602683ce38&from=serp&vjs=3
# extracting 7 job keywords...
# [] ['werkt samen', 'analytisch', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=36f30dca3983566e&from=serp&vjs=3
# extracting 8 job keywords...
# ['sql'] ['communicatieve vaardigheden', 'advies', 'zelfstandig', 'enthousiast', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0759dc70e8bff72b&from=serp&vjs=3
# extracting 9 job keywords...
# ['qlikview'] ['adviseur', 'werkt samen', 'analytisch', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=97dad8f725519cda&from=serp&vjs=3
# extracting 10 job keywords...
# ['sap', 'python', 'java'] ['adviseur', 'samenwerken', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=fdf920a2473eb43f&from=serp&vjs=3
# extracting 11 job keywords...
# ['sap', 'powerbi', 'sql'] ['proactief', 'analytisch', 'vertalen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0d5a066a9280efb7&from=serp&vjs=3
# extracting 12 job keywords...
# [] ['agile', 'werkt samen', 'analytisch', 'realiseren', 'gedreven'] 1
# https://www.indeed.nl/cmp/Bi--iB/jobs/Sales-Consultant-0c47f89413fc4d6e?vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39bmdg9ooiblf&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39bq899ooic6g&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39bu8e9ooi9m6&from=serp&alid=3&advn=6124692058421937
# extracting 5 page of job searching results...
# extracting 0 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39ca7g9ndjeap&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 1 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39cdhp9ndjfkq&from=serp&alid=3&advn=8245509577778884
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39chhr9ndjbgt&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['sas'] ['communicatieve vaardigheden', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=f2b1159e2ac0893d&from=serp&vjs=3
# extracting 4 job keywords...
# ['sql'] ['werkt samen', 'zelfstandig', 'vertalen'] 1
# https://www.indeed.nl/cmp/Q--TC-Nederland-B.V./jobs/Q-Tc-Is-Zoek-Naar-Medior-Bi-Consultants-cfb8c8a5413b97bb?vjs=3
# extracting 5 job keywords...
# ['sap', 'powerbi', 'qlik', 'tableau'] ['proactief', 'adviseur', 'analytisch', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1384396c19852061&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap', 'powerbi', 'sql'] ['advies', 'samenwerken', 'vertalen', 'realiseren', 'ondernemen', 'adviseer', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=37623c3a5ce3b935&from=serp&vjs=3
# extracting 7 job keywords...
# ['powerbi', 'qlik', 'r', 'tableau', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=a7e7a64fb9b3bf52&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'powerbi', 'excel', 'sql'] ['analytisch', 'enthousiast', 'analyseren', 'creatief', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=bcac0926ad308161&from=serp&vjs=3
# extracting 9 job keywords...
# ['powerbi', 'qlik', 'tableau', 'sql'] ['analytisch vermogen', 'proactief', 'analytisch', 'zelfstandig', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=e223245e851dd319&from=serp&vjs=3
# extracting 10 job keywords...
# ['sql'] ['analytisch', 'enthousiast', 'analyseren', 'oplossingsgericht', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=e666f5b3c745ed70&from=serp&vjs=3
# extracting 11 job keywords...
# ['sap', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=4621b506cb9d9f35&from=serp&vjs=3
# extracting 12 job keywords...
# ['sap', 'r'] ['agile', 'scrum', 'advies', 'zelfstandig', 'vertalen', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=234e0d2ebd5177b2&from=serp&vjs=3
# extracting 13 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39dovd9ndjcqq&from=serp&alid=3&advn=713903982049763
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39ds1u9ndjdu4&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39dvf49ndjaji&from=serp&alid=3&advn=6124692058421937
# extracting 6 page of job searching results...
# extracting 0 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39e3mc9ndjfkc&from=serp&alid=3&advn=6124692058421937
# extracting 1 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39e6a59ndjbvj&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39e8rn9ndj91n&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['sap'] ['agile', 'scrum', 'samenwerken', 'analytisch', 'enthousiast', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3ca743ea67c14ff8&from=serp&vjs=3
# extracting 4 job keywords...
# ['sap'] ['communicatieve vaardigheden', 'analytisch', 'zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=cccd79266c5ad652&from=serp&vjs=3
# extracting 5 job keywords...
# ['qlik', 'qlikview', 'sql'] ['communicatieve vaardigheden', 'zelfstandig', 'realiseren', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=62f22217fd72c33d&from=serp&vjs=3
# extracting 6 job keywords...
# ['sql', 'sap', 'powerbi'] ['communicatieve vaardigheden'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6989b202dc4400e8&from=serp&vjs=3
# extracting 7 job keywords...
# ['qlikview', 'sap', 'scala'] ['analytisch', 'zelfstandig', 'enthousiast', 'adviseer', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d6b258d3ed2de118&from=serp&vjs=3
# extracting 8 job keywords...
# ['excel', 'tableau', 'sql'] ['agile', 'advies', 'samenwerken', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4c842c617c1a4912&from=serp&vjs=3
# extracting 9 job keywords...
# [] ['werkt nauw samen', 'analytisch', 'enthousiast', 'analyseren', 'adviseer', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b12fe97db4783756&from=serp&vjs=3
# extracting 10 job keywords...
# ['hadoop', 'sql', 'excel', 'powerbi'] ['communicatieve vaardigheden', 'analytisch', 'zelfstandig', 'realiseren', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/cmp/ICTJobhouse-BV/jobs/Bi-Consultant-Developer-d966d38282e11174?vjs=3
# extracting 11 job keywords...
# ['sql', 'sap'] ['agile', 'scrum', 'samenwerken', 'analytisch', 'enthousiast', 'analyseren', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6c833a706c6aa3f8&from=serp&vjs=3
# extracting 12 job keywords...
# ['sql'] ['werkt nauw samen', 'oplossingsgericht', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3dd0f6b2bf6f45c5&from=serp&vjs=3
# extracting 13 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39ffel9ndjc6h&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 14 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39fhtu9ndj87i&from=serp&alid=3&advn=8245509577778884
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39fl9d9ndjfs2&from=serp&alid=3&advn=2180790811884654
# extracting 7 page of job searching results...
# extracting 0 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39fpub9ndj91h&from=serp&alid=3&advn=6124692058421937
# extracting 1 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39ftfp9ndje1f&from=serp&alid=3&advn=8245509577778884
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39g0359ndjb64&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['sap'] ['agile', 'scrum', 'werkt samen', 'zelfstandig', 'vertalen', 'realiseren', 'oplossingsgericht', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=82680d6055e40e54&from=serp&vjs=3
# extracting 4 job keywords...
# ['sap'] ['communicatieve vaardigheden', 'werkt samen', 'realiseren', 'oplossingsgericht', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d8c3b7acb4d33d68&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap', 'r'] ['analytisch', 'zelfstandig', 'vertalen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=f295c3c26affa556&from=serp&vjs=3
# extracting 6 job keywords...
# [] ['agile', 'scrum', 'analytisch', 'zelfstandig', 'vertalen', 'realiseren', 'prioriteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=bdfabff52b01adee&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap'] ['communicatieve vaardigheden', 'agile', 'analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'inventariseren', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4931d6f65efe5887&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap'] ['agile', 'scrum', 'samenwerken', 'analytisch', 'enthousiast', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=151759e230dd701e&from=serp&vjs=3
# extracting 9 job keywords...
# ['python', 'sql', 'excel', 'powerbi', 'qlik', 'r'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=51803c8fffba23dd&from=serp&vjs=3
# extracting 10 job keywords...
# ['sap'] ['communicatieve vaardigheden', 'advies', 'adviseur', 'samenwerken', 'realiseren', 'adviseer', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0aeb2c2e4ab95355&from=serp&vjs=3
# extracting 11 job keywords...
# ['sas', 'sql'] ['samenwerken', 'enthousiast', 'gedreven', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=82ccdcad8b2e6379&from=serp&vjs=3
# extracting 12 job keywords...
# ['excel'] ['projectmanagement', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=48f90d2de7b1c71d&from=serp&vjs=3
# extracting 13 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39h4mu9ndj9ef&from=serp&alid=3&advn=713903982049763
# extracting 14 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39h8ig9ndjb64&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39hc569ndj8qd&from=serp&alid=3&advn=2180790811884654
# extracting 8 page of job searching results...
# extracting 0 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39hfoe9ndjeac&from=serp&alid=3&advn=6124692058421937
# extracting 1 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39hj4m9ndjf3i&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 2 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39hmb19ndjc1l&from=serp&alid=3&advn=713903982049763
# extracting 3 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39hp4m9ndjf1u&from=serp&alid=3&advn=2421485629829485
# extracting 4 job keywords...
# ['powerbi', 'qlik', 'r', 'tableau', 'sql'] ['proactief', 'advies', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=37a3bbc1b237613a&from=serp&vjs=3
# extracting 5 job keywords...
# [] ['analytisch vermogen', 'communicatieve vaardigheden', 'samenwerken', 'analytisch', 'zelfstandig', 'analyseren', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=970ef4d1234ac71c&from=serp&vjs=3
# extracting 6 job keywords...
# [] ['gedreven', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0f95e2b8ddf7e54a&from=serp&vjs=3
# extracting 7 job keywords...
# ['qlikview', 'sap'] ['analytisch vermogen', 'advies', 'analytisch', 'zelfstandig', 'realiseren', 'ondernemen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9ab6b7ad0c628511&from=serp&vjs=3
# extracting 8 job keywords...
# ['sql'] ['projectmanagement', 'communicatieve vaardigheden', 'enthousiast', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=cc7ae7757fbff12e&from=serp&vjs=3
# extracting 9 job keywords...
# ['sql'] ['analytisch vermogen', 'samenwerken', 'analytisch', 'realiseren', 'ondernemen', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=88ed00bf7e48632c&from=serp&vjs=3
# extracting 10 job keywords...
# ['sas', 'sql', 'excel', 'r'] ['samenwerken', 'zelfstandig', 'enthousiast', 'analyseren', 'adviseer', 'klantgericht', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b8529fc3389a2a04&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['agile', 'scrum', 'samenwerken', 'enthousiast', 'vertalen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=58644f0e92114d75&from=serp&vjs=3
# extracting 12 job keywords...
# ['python', 'sas', 'sql', 'r'] ['projectmanagement', 'enthousiast', 'ondernemen'] 1
# https://www.indeed.nl/vacature-bekijken?jk=74dc71477a4911d1&from=serp&vjs=3
# extracting 13 job keywords...
# ['powerbi', 'python', 'tableau'] ['analytisch vermogen', 'agile', 'scrum', 'advies', 'adviseur', 'analytisch', 'realiseren', 'adviseer', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=ffe19a8801b562b5&from=serp&vjs=3
# extracting 14 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39isuf9ndjc51&from=serp&alid=3&advn=8245509577778884
# extracting 15 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39ivp89ndjf76&from=serp&alid=3&advn=2180790811884654
# extracting 9 page of job searching results...
# extracting 0 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39j4q29ndj8d4&from=serp&alid=3&advn=2180790811884654
# extracting 1 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl39j8e59ndj900&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39jc8r9ndjf6i&from=serp&alid=3&advn=2421485629829485
# extracting 3 job keywords...
# ['excel'] ['projectmanagement', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=48f90d2de7b1c71d&from=serp&vjs=3
# extracting 4 job keywords...
# [] ['agile', 'scrum', 'samenwerken', 'enthousiast', 'vertalen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=58644f0e92114d75&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap', 'powerbi', 'qlik', 'sql'] ['communicatieve vaardigheden', 'analytisch', 'vertalen', 'oplossingsgericht', 'klantgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3820567ae64fd9a7&from=serp&vjs=3
# extracting 6 job keywords...
# ['sql'] ['projectmanagement', 'communicatieve vaardigheden', 'enthousiast', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=cc7ae7757fbff12e&from=serp&vjs=3
# extracting 7 job keywords...
# ['matlab', 'python', 'sas', 'r', 'spss'] ['communicatieve vaardigheden', 'analytisch', 'vertalen', 'analyseren', 'klantgericht', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6790ba5bb2f2fb38&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'r'] ['analytisch', 'zelfstandig', 'vertalen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=f295c3c26affa556&from=serp&vjs=3
# extracting 9 job keywords...
# ['python', 'sas', 'sql', 'r'] ['projectmanagement', 'enthousiast', 'ondernemen'] 1
# https://www.indeed.nl/vacature-bekijken?jk=74dc71477a4911d1&from=serp&vjs=3
# extracting 10 job keywords...
# ['hadoop', 'tableau', 'sap', 'qlik', 'r'] ['projectmanagement', 'samenwerken', 'analytisch', 'zelfstandig', 'vertalen', 'realiseren', 'ondernemen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=77aeed636810b5ac&from=serp&vjs=3
# extracting 11 job keywords...
# ['powerbi', 'qlik', 'tableau', 'sql'] ['analytisch vermogen', 'proactief', 'analytisch', 'zelfstandig', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=5165d58ef49806b8&from=serp&vjs=3
# extracting 12 job keywords...
# ['sql'] ['advies', 'adviseur', 'realiseren', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=8012a4f2153e476b&from=serp&vjs=3
# extracting 13 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39khtl9ndjc3e&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 14 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39kks79ndjft3&from=serp&alid=3&advn=8245509577778884
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39ko2n9ndjds3&from=serp&alid=3&advn=6124692058421937
# extracting 10 page of job searching results...
# extracting 0 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39l4oa94opafi&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 1 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39l97n94opf1e&from=serp&alid=3&advn=8245509577778884
# extracting 2 job keywords...
# ['sas', 'sql'] ['analytisch', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71870903e1c04534&tk=1cl39lbr494opc83&from=serp&alid=3&advn=2723736679244663
# extracting 3 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39lfnj94opft5&from=serp&alid=3&advn=2421485629829485
# extracting 4 job keywords...
# ['sap', 'qlikview', 'sas', 'sql'] ['adviseur', 'zelfstandig', 'vertalen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=522a9c7e87e1cdbe&from=serp&vjs=3
# extracting 5 job keywords...
# [] ['enthousiast', 'oplossingsgericht', 'oplossingsgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=aaade5e9bd6d018b&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap', 'd3', 'powerbi'] ['agile', 'scrum', 'advies', 'klantgericht', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4e08456a4e7f40e4&from=serp&vjs=3
# extracting 7 job keywords...
# ['python', 'sql', 'tableau', 'powerbi', 'r', 'spss'] ['agile'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6034b3a0399934c6&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'powerbi', 'qlikview'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=3b9a4787e5cfba58&from=serp&vjs=3
# extracting 9 job keywords...
# [] ['communicatieve vaardigheden', 'enthousiast', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4cf3af712692d6ba&from=serp&vjs=3
# extracting 10 job keywords...
# ['r'] ['adviseur', 'samenwerken', 'zelfstandig', 'realiseren', 'adviseer', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b9101c22a022b854&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['projectmanagement', 'vertalen', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=88f46a428589d0e3&from=serp&vjs=3
# extracting 12 job keywords...
# ['qlik', 'tableau'] ['enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=8fdebadc19b98c61&from=serp&vjs=3
# extracting 13 job keywords...
# ['java'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=d927c92a2d7674a7&from=serp&vjs=3
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39mmms94opac1&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39mqov94op8ns&from=serp&alid=3&advn=6124692058421937
# extracting 11 page of job searching results...
# extracting 0 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39mvao94opa9g&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 1 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39n2cd94opel3&from=serp&alid=3&advn=8245509577778884
# extracting 2 job keywords...
# ['sas', 'sql'] ['analytisch', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71870903e1c04534&tk=1cl39n5am94opaud&from=serp&alid=3&advn=2723736679244663
# extracting 3 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39n8vr94opb5o&from=serp&alid=3&advn=2421485629829485
# extracting 4 job keywords...
# [] ['communicatieve vaardigheden', 'zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0d0c2dfa922daf3a&from=serp&vjs=3
# extracting 5 job keywords...
# ['sql'] ['agile', 'adviseur', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9daf456904a9962d&from=serp&vjs=3
# extracting 6 job keywords...
# [] [] 1
# https://www.indeed.nl/cmp/Next-Ventures/jobs/Data-Analytics-Consultant-03f7943323551276?vjs=3
# extracting 7 job keywords...
# ['sap', 'qlik', 'hadoop', 'sas', 'tableau', 'sql'] ['zelfstandig', 'ondernemen', 'gedreven'] 1
# https://www.indeed.nl/cmp/DIKW-Intelligence/jobs/Senior-Business-Intelligence-Consultant-3d884fa8027dedb5?vjs=3
# extracting 8 job keywords...
# [] ['communicatieve vaardigheden', 'ondernemen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=a385b308ee2c7c26&from=serp&vjs=3
# extracting 9 job keywords...
# [] ['communicatieve vaardigheden', 'ondernemen'] 1
# https://www.indeed.nl/vacature-bekijken?jk=353fca19138dd1cd&from=serp&vjs=3
# extracting 10 job keywords...
# ['sql', 'java'] ['communicatieve vaardigheden', 'agile', 'scrum', 'analytisch', 'vertalen', 'analyseren', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=89e52e24e1dd5c3c&from=serp&vjs=3
# extracting 11 job keywords...
# ['sas', 'sql'] ['samenwerken', 'analytisch', 'oplossingsgericht', 'gedreven', 'creatief', 'meedenkend', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4fe7f175a0375e61&from=serp&vjs=3
# extracting 12 job keywords...
# ['sap', 'qlik'] ['zelfstandig', 'enthousiast', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b90a32e70c43d3c4&from=serp&vjs=3
# extracting 13 job keywords...
# ['sas'] ['communicatieve vaardigheden', 'analytisch', 'zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b55b9c84b2850011&from=serp&vjs=3
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39ogb394opfko&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39on8i94opdtc&from=serp&alid=3&advn=6124692058421937
# extracting 12 page of job searching results...
# extracting 0 job keywords...
# ['sas', 'sql'] ['analytisch', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71870903e1c04534&tk=1cl39or5i94op8gh&from=serp&alid=3&advn=2723736679244663
# extracting 1 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39ouvc94opbi2&from=serp&alid=3&advn=2180790811884654
# extracting 2 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39p25h94opd11&from=serp&alid=3&advn=6124692058421937
# extracting 3 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39p4u694opb4k&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 4 job keywords...
# [] ['advies', 'werkt nauw samen', 'analytisch', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b29d8e45b3a00ac7&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap', 'powerbi', 'sql'] ['communicatieve vaardigheden', 'advies', 'analytisch', 'zelfstandig', 'vertalen', 'realiseren', 'adviseer', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d604971be532f052&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap'] ['werkt samen', 'zelfstandig', 'enthousiast', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d3be1056eb80e935&from=serp&vjs=3
# extracting 7 job keywords...
# [] ['communicatieve vaardigheden', 'enthousiast', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d72170ea3aad79f4&from=serp&vjs=3
# extracting 8 job keywords...
# ['sql', 'sap', 'qlik'] ['analytisch', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=bcb21eca2cc45597&from=serp&vjs=3
# extracting 9 job keywords...
# ['sap', 'powerbi', 'sql'] ['adviseur', 'inventariseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=5059819a75b3fd28&from=serp&vjs=3
# extracting 10 job keywords...
# ['sap', 'sas', 'sql'] ['adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1788fca96fb00887&from=serp&vjs=3
# extracting 11 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'tableau', 'powerbi', 'r', 'spark', 'nosql'] ['agile', 'scrum', 'advies', 'werkt samen', 'adviseer', 'gedreven', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=5b9d4eee8b998d29&from=serp&vjs=3
# extracting 12 job keywords...
# ['sas', 'sql'] ['proactief', 'samenwerken', 'oplossingsgericht', 'creatief', 'meedenkend', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3511429d9cf977eb&from=serp&vjs=3
# extracting 13 job keywords...
# ['powerbi', 'python', 'tableau'] ['analytisch vermogen', 'agile', 'scrum', 'advies', 'adviseur', 'analytisch', 'realiseren', 'adviseer', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=ffe19a8801b562b5&from=serp&vjs=3
# extracting 14 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39qfbh94opcb7&from=serp&alid=3&advn=2421485629829485
# extracting 15 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39qi7n94opcpq&from=serp&alid=3&advn=8245509577778884
# extracting 13 page of job searching results...
# extracting 0 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39qmjt94opctb&from=serp&alid=3&advn=2180790811884654
# extracting 1 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl39qq7q94opbgj&from=serp&alid=3&advn=6124692058421937
# extracting 2 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl39qsut94opfmn&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 3 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl39r1nu94op8ie&from=serp&alid=3&advn=8245509577778884
# extracting 4 job keywords...
# ['sas', 'sql'] ['proactief', 'samenwerken', 'oplossingsgericht', 'creatief', 'meedenkend', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9c6c9880261ac6e2&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap', 'powerbi', 'excel'] ['communicatieve vaardigheden', 'advies', 'adviseur'] 1
# https://www.indeed.nl/vacature-bekijken?jk=e7d062ec134b2738&from=serp&vjs=3
# extracting 6 job keywords...
# [] ['communicatieve vaardigheden', 'adviseur', 'werkt samen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=bc2f13d90ced1520&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap', 'sas'] ['communicatieve vaardigheden', 'adviseur', 'werkt samen', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=59191878cd4e51ce&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'powerbi'] [] 1
# https://www.indeed.nl/cmp/Next-Ventures/jobs/Bi-Consultant-633167dcb6c69dac?vjs=3
# extracting 9 job keywords...
# ['sap', 'sql', 'java'] ['werkt samen', 'analytisch', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=51adb9de2c3f2a3d&from=serp&vjs=3
# extracting 10 job keywords...
# ['sql'] ['samenwerken', 'analytisch', 'oplossingsgericht', 'gedreven', 'creatief', 'meedenkend', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=e8ff4ac6bb2a120a&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['advies', 'adviseur', 'zelfstandig', 'realiseren', 'adviseer', 'klantgericht'] 1
# https://www.indeed.nl/cmp/BECIS-B.V./jobs/Senior-Informatieadviseur-c02fb8fb0673b751?vjs=3
# extracting 12 job keywords...
# ['python', 'sql', 'java', 'c++', 'excel', 'qlikview', 'tableau', 'sap', 'powerbi'] ['werkt samen', 'samenwerken', 'analytisch'] 1
# https://www.indeed.nl/vacature-bekijken?jk=ffcdc67cc4336855&from=serp&vjs=3
# extracting 13 job keywords...
# ['matlab', 'python', 'sql', 'tableau', 'r'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=addd11debff2109e&from=serp&vjs=3
# extracting 14 job keywords...
# ['sas', 'sql'] ['analytisch', 'resultaatgericht', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71870903e1c04534&tk=1cl39s8ts94op81d&from=serp&alid=3&advn=2723736679244663
# extracting 15 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl39sc0c94opc3b&from=serp&alid=3&advn=2421485629829485
# extracting 14 page of job searching results...
# extracting 0 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl39sg3l94opdgt&from=serp&alid=3&advn=2180790811884654
# extracting 1 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# ...
# extracting 6 job keywords...
# ['sap'] ['advies', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=319bd98bef16b78d&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=30d175014af8298c&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap', 'qlikview'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=a282caf1db14e604&from=serp&vjs=3
# extracting 9 job keywords...
# ['powerbi'] ['proactief', 'analytisch', 'zelfstandig', 'enthousiast', 'ondernemen'] 1
# https://www.indeed.nl/vacature-bekijken?jk=639dd4df85579c6f&from=serp&vjs=3
# extracting 10 job keywords...
# [] ['agile'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1483f6eb6e4e020e&from=serp&vjs=3
# extracting 11 job keywords...
# ['powerbi', 'java'] ['communicatieve vaardigheden', 'agile', 'scrum', 'analytisch', 'zelfstandig', 'analyseren', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a80bcded3c3d22e&from=serp&vjs=3
# extracting 12 job keywords...
# ['sap', 'powerbi', 'r'] ['zelfstandig', 'enthousiast', 'vertalen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d2a57c45a54e586f&from=serp&vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl3b743j94st8r6&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl3b778u94stdu7&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3b7aps94stbrt&from=serp&alid=3&advn=6124692058421937
# extracting 42 page of job searching results...
# extracting 0 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl3b7da394st9ab&from=serp&alid=3&advn=2421485629829485
# extracting 1 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3b7ge094stff6&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl3b7iig94stb3k&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 3 job keywords...
# [] ['analyseren', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d9fd93e3d6ea6089&from=serp&vjs=3
# extracting 4 job keywords...
# ['powerbi', 'tableau', 'sql'] ['adviseer', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=246fa7206b00d7f1&from=serp&vjs=3
# extracting 5 job keywords...
# [] ['agile', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=08a29782b6696f40&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=6fdeaa020f5d90fc&from=serp&vjs=3
# extracting 7 job keywords...
# [] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=c5c6e856e33d07bb&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap'] ['analytisch vermogen', 'analytisch', 'enthousiast', 'realiseren', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=14853e2da9ff3d24&from=serp&vjs=3
# extracting 9 job keywords...
# ['sql', 'sap'] ['proactief', 'agile', 'scrum', 'werkt samen', 'analytisch', 'planmatig', 'enthousiast', 'gedreven', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=43193b62f0c97167&from=serp&vjs=3
# extracting 10 job keywords...
# [] ['agile', 'analytisch', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d1d2ca5ca995c19a&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['adviseur', 'analytisch', 'zelfstandig', 'adviseer', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=7a4aaea85157c2f8&from=serp&vjs=3
# extracting 12 job keywords...
# ['powerbi', 'spark'] ['werkt samen', 'analytisch', 'zelfstandig', 'ondernemen', 'adviseer', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=4f41a9ce99b0e35d&from=serp&vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl3b8ma594stb45&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl3b8okc94st9uk&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3b8rje94std1s&from=serp&alid=3&advn=6124692058421937
# extracting 43 page of job searching results...
# extracting 0 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl3b8vkv94stbfs&from=serp&alid=3&advn=2421485629829485
# extracting 1 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3b92oe94st9th&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl3b94u694st8ca&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 3 job keywords...
# ['sql'] ['enthousiast', 'inventariseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=779a097c046301a9&from=serp&vjs=3
# extracting 4 job keywords...
# ['sql'] ['analytisch', 'enthousiast', 'analyseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=c6bf1897ea2da6fb&from=serp&vjs=3
# extracting 5 job keywords...
# ['java'] ['communicatieve vaardigheden', 'agile', 'scrum', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=439af310e4e33b9a&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap', 'qlikview', 'sas', 'tableau', 'sql'] ['scrum', 'adviseur', 'zelfstandig', 'vertalen', 'ondernemen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3ff9351ea1ccc23a&from=serp&vjs=3
# extracting 7 job keywords...
# ['sql', 'tableau', 'powerbi'] ['realiseren', 'adviseer', 'klantgericht'] 1
# https://www.indeed.nl/cmp/ItaQ/jobs/Dwh-Developer-6e563232a2051426?vjs=3
# extracting 8 job keywords...
# ['sap', 'powerbi'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=e6dd592b88a8d31d&from=serp&vjs=3
# extracting 9 job keywords...
# ['sap'] ['zelfstandig', 'vertalen', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=9b72cbb857afd585&from=serp&vjs=3
# extracting 10 job keywords...
# ['excel'] ['projectmanagement', 'agile', 'scrum', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=b7d2daae9456f9c0&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['communicatieve vaardigheden', 'realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=cd85af1183ede8b7&from=serp&vjs=3
# extracting 12 job keywords...
# ['sap'] ['presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=be470d7f6b298da2&from=serp&vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl3ba30i94stddd&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl3ba5je94sta9k&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3ba8tj94sta38&from=serp&alid=3&advn=6124692058421937
# extracting 44 page of job searching results...
# extracting 0 job keywords...
# ['powerbi', 'qlik', 'python', 'hadoop', 'spark', 'tableau', 'sql', 'java'] ['werkt samen', 'analytisch'] 1
# https://www.indeed.nl/vacature-bekijken?jk=3b8f0928331376d2&from=serp&vjs=3
# extracting 1 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl3bagm994stbd6&from=serp&alid=3&advn=2421485629829485
# extracting 2 job keywords...
# ['r', 'sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3baire94stcah&from=serp&alid=3&advn=713903982049763
# extracting 3 job keywords...
# ['sql', 'powerbi', 'r'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl3bam8k94stfm4&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 4 job keywords...
# ['sap', 'qlikview'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=649dc8de233c9299&from=serp&vjs=3
# extracting 5 job keywords...
# ['sap'] ['zelfstandig'] 1
# https://www.indeed.nl/vacature-bekijken?jk=f21dfe9d0ac60a73&from=serp&vjs=3
# extracting 6 job keywords...
# ['powerbi'] ['realiseren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=2e9f630d2dd1dd92&from=serp&vjs=3
# extracting 7 job keywords...
# ['sap'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=26d5ace02e1aba98&from=serp&vjs=3
# extracting 8 job keywords...
# ['d3'] ['analytisch', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1d2f32b77d52ce9c&from=serp&vjs=3
# extracting 9 job keywords...
# ['sql'] ['advies', 'ondernemen', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=ce8186f8c33eae24&from=serp&vjs=3
# extracting 10 job keywords...
# ['powerpoint', 'excel', 'r', 'spss'] ['zelfstandig', 'ondernemen'] 1
# https://www.indeed.nl/vacature-bekijken?jk=10d0bee83b278e34&from=serp&vjs=3
# extracting 11 job keywords...
# ['sap'] ['projectmanagement', 'adviseur'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d7db147dbd5a142b&from=serp&vjs=3
# extracting 12 job keywords...
# ['sql', 'tableau', 'powerbi'] ['zelfstandig', 'adviseer', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=cc40fb3130ea99e4&from=serp&vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl3bbikp94std6m&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl3bbm0o94stdgn&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3bboll94st9id&from=serp&alid=3&advn=6124692058421937
# extracting 45 page of job searching results...
# extracting 0 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl3bc2649ooiaev&from=serp&alid=3&advn=2421485629829485
# extracting 1 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3bc53f9ooidp4&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# ['powerbi', 'r', 'sql'] ['werkt samen', 'enthousiast', 'vertalen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=6d028a6a0c87e41c&q=BI+consultant&from=web&advn=2180790811884654&sjdu=XGcMNTSedHgn69ge8Rv0-QczTG3nlC0EU2f2klO71b63VlKMcsXkzpKWOnuUTRA28Y-JNPk6g2f94QTYfUqzrRFHKK5gkv3k4Jv2v0R8T9NZ3fASCkljWXRWvynqtS9y2vQaw46jDDkaMfs5GwNu36PqQA1LV3jhFCCDzCMd938&acatk=1cl3bc87q9ooi8fs&pub=4a1b367933fd867b19b072952f68dceb&vjs=3
# extracting 3 job keywords...
# ['sql'] ['werkt samen', 'samenwerken', 'analytisch', 'presenteren'] 1
# https://www.indeed.nl/vacature-bekijken?jk=d1b247fa97a23eac&from=serp&vjs=3
# extracting 4 job keywords...
# [] ['analytisch vermogen', 'advies', 'adviseur', 'samenwerken', 'analytisch', 'realiseren', 'klantgericht', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=1b6e5777a59700de&from=serp&vjs=3
# extracting 5 job keywords...
# ['php', 'java'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=7fff5e33b607bd3b&from=serp&vjs=3
# extracting 6 job keywords...
# ['sap', 'powerbi', 'qlik'] ['zelfstandig', 'enthousiast', 'oplossingsgericht', 'gedreven', 'oplossingsgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=477fca50c560cb4f&from=serp&vjs=3
# extracting 7 job keywords...
# ['sas', 'tableau', 'sql'] ['enthousiast', 'realiseren', 'ondernemen', 'klantgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=c70388de958d73f6&from=serp&vjs=3
# extracting 8 job keywords...
# ['sap'] ['analytisch', 'adviseer'] 1
# https://www.indeed.nl/vacature-bekijken?jk=2efb7fa0d769fba0&from=serp&vjs=3
# extracting 9 job keywords...
# ['powerbi', 'qlik', 'tableau', 'sql'] ['advies', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=85793bb212e568cd&from=serp&vjs=3
# extracting 10 job keywords...
# ['sap'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=706860dc939fe949&from=serp&vjs=3
# extracting 11 job keywords...
# [] ['agile', 'analytisch', 'zelfstandig', 'ondernemen', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=71b0aff1e94a23b0&from=serp&vjs=3
# extracting 12 job keywords...
# ['python', 'c++', 'pig', 'hadoop', 'spark', 'scala', 'java'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=735e4e8fb261b3c8&from=serp&vjs=3
# extracting 13 job keywords...
# ['python', 'hadoop', 'sql', 'java', 'c++', 'r', 'spark', 'nosql'] ['scrum', 'advies', 'werkt samen', 'gedreven'] 1
# https://www.indeed.nl/vacature-bekijken?jk=24115a299a2e1531&tk=1cl3bd9ag9ooi8ri&from=serp&alid=3&advn=8245509577778884
# extracting 14 job keywords...
# ['powerbi', 'sql'] ['advies', 'werkt samen', 'zelfstandig', 'enthousiast'] 1
# https://www.indeed.nl/vacature-bekijken?jk=0a8fa72b3f5e0492&tk=1cl3bdc0h9ooi8m1&from=serp&alid=3&advn=2180790811884654
# extracting 15 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3bdfc89ooi80r&from=serp&alid=3&advn=6124692058421937
# extracting 46 page of job searching results...
# extracting 0 job keywords...
# [] ['analytisch', 'zelfstandig', 'enthousiast', 'vertalen', 'analyseren', 'klantgericht', 'creatief'] 1
# https://www.indeed.nl/vacature-bekijken?jk=209af06ed43c644b&tk=1cl3bdj0d9ooifq3&from=serp&alid=3&advn=2421485629829485
# extracting 1 job keywords...
# ['sql'] [] 1
# https://www.indeed.nl/vacature-bekijken?jk=9a8fdc01f707b1fe&tk=1cl3bdl5l9ooi922&from=serp&alid=3&advn=713903982049763
# extracting 2 job keywords...
# ['sap', 'sas'] ['agile', 'vertalen', 'inventariseren', 'analyseren', 'realiseren', 'ondernemen', 'gedreven', 'resultaatgericht'] 1
# https://www.indeed.nl/vacature-bekijken?jk=638eb3aa8de6ce6f&tk=1cl3bdohc9ooi838&from=serp&alid=3&advn=6124692058421937

# %%
df.to_csv("skills_for_BIconsultant.csv")
